# %% [markdown]
# # Matplotlib
# - 대표적인 시각화 라이브러리

# %% [markdown]
# ## Install & Import

# %%
# !pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import matplotlib.pyplot as plt
import numpy as np
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# ## 기본 그래프 (plot)

# %%
plt.plot([1,2,3,4,5,6,5,4,3,2,1])
plt.show()

# %%
## sin 함수 그려보기
x = np.arange(0, 10, 1)
y = np.sin(x)

plt.plot(x,y)
plt.plot(x,y-1)
plt.plot(x,y-3)

plt.xlabel('time')
plt.ylabel('Amplitude') # 진폭

plt.title("sin graph")
plt.grid()

plt.show()

# %%
plt.plot(x, np.sin(x), label="sin")
plt.plot(x, np.cos(x), label="cos")

# 격자
plt.grid()

# x,y축 이름
plt.xlabel("time")
plt.ylabel("Amplitude")

# 그래프 제목
plt.title("sin & cos graph")

# x,y lim 값
# plt.xlim(0, np.pi)
# plt.ylim(-1.2,1.2)

# 범례 (legend)
plt.legend(loc=(1.05,0.05)) # 위치 => x,y 값 기준
plt.show() # 이미지 볼 때 Shift + 마우스 우클릭

# %% [markdown]
# ### 스타일

# %%
# plt.plot(x,y, linewidth=10)
plt.plot(x,y, marker='X', markersize=20, markeredgecolor='red')

# %%
# plt.plot(x,y, linestyle='--', color='#ccff11')
plt.figure(facecolor='red')

# figure -> 그래프 사이즈
plt.figure(figsize=(100, 10), dpi=600) # dpi=dots per inch


# format
plt.plot(x,y, 'rX--') # color, marker, linestyle
plt.plot(x,y-1, 'bX--', alpha=0.1) # color, marker, linestyle

plt.show()

# %%
x_value = np.arange(1, 20, 2)
y_value = 2*x_value

plt.plot(x_value, y_value, color='red', marker='o', linestyle='dashed', linewidth=2, markersize=6, label='line')
plt.bar(x_value, y_value, color='pink', label='bar')

plt.xlabel("X Label")
plt.ylabel("Y Label")

plt.legend()

plt.title("Growth Report")

plt.show()

# %%
x_value1 = np.arange(1, 10)
x_value2 = np.arange(1, 20)

y_value1 = 2*x_value1
y_value2 = 2*x_value2

fig, (ax_01, ax_02) = plt.subplots(nrows=1, ncols=2, figsize=(12,6))

ax_01.plot(x_value1, y_value1, color='red', marker='o',
           linestyle='dashed', linewidth=2, markersize=6, label="ax_01")
ax_02.bar(x_value2, y_value2, color='pink', label='ax_02')

ax_01.legend()
ax_02.legend()

plt.show()

# %%
import numpy as np

x_value_01 = np.arange(1, 10)
x_value_02 = np.arange(1, 20)
y_value_01 = 2 * x_value_01
y_value_02 = 2 * x_value_02

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(12, 6)) # subplot은 하나씩 설정, subplots은 한번에 설정.

ax[0][0].plot(x_value_01, y_value_01, color='red', marker='o', linestyle='dashed', linewidth=2, markersize=6, label='temp_01')
ax[0][1].bar(x_value_02, y_value_02, color='green', label='temp_02')
ax[1][0].plot(x_value_01, y_value_01, color='green', marker='o', linestyle='dashed', linewidth=2, markersize=6, label='temp_03')
ax[1][1].bar(x_value_02, y_value_02, color='red', label='temp_04')

ax[0][0].set_xlabel('0,0의 그래프 라벨')
ax[0][1].set_xlabel('ax[0][1] x 라벨')
ax[1][0].set_xlabel('ax[1][0] x 라벨')
ax[1][1].set_xlabel('ax[1][1] x 라벨')

ax[0][0].legend()
ax[0][1].legend()
ax[1][0].legend()
ax[1][1].legend()

plt.title("한글 깨짐 현상 체크")
#plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## 산점도 그래프 (Scatter)
#
# - 좌표를 이용해 좌표상의 점들을 표시한다. => 두 변수 간의 관계를 나타내기 위해서 표현한다.

# %%
# import matplotlib as mpl
# import matplotlib.pyplot as plt
# import matplotlib.font_manager as fm

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
# font_name = fm.FontProperties(fname=path, size=10).get_name()
# print(font_name)
# plt.rc('font', family=font_name)
# mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumBarunGothic

# %%
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 31 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# ...

# %%
import numpy as np

x_value_01 = np.arange(1, 10)
x_value_02 = np.arange(1, 20)
y_value_01 = 2 * x_value_01
y_value_02 = 2 * x_value_02

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(12, 6)) # subplot은 하나씩 설정, subplots은 한번에 설정.

ax[0][0].plot(x_value_01, y_value_01, color='red', marker='o', linestyle='dashed', linewidth=2, markersize=6, label='temp_01')
ax[0][1].bar(x_value_02, y_value_02, color='green', label='temp_02')
ax[1][0].plot(x_value_01, y_value_01, color='green', marker='o', linestyle='dashed', linewidth=2, markersize=6, label='temp_03')
ax[1][1].bar(x_value_02, y_value_02, color='red', label='temp_04')

ax[0][0].set_xlabel('0,0의 그래프 라벨')
ax[0][1].set_xlabel('ax[0][1] x 라벨')
ax[1][0].set_xlabel('ax[1][0] x 라벨')
ax[1][1].set_xlabel('ax[1][1] x 라벨')

ax[0][0].legend()
ax[0][1].legend()
ax[1][0].legend()
ax[1][1].legend()

plt.title("한글 깨짐 현상 체크")
#plt.legend()
plt.show()

# %%
x1 = np.random.rand(100) - 1.0
x2 = np.random.rand(100)
y1 = np.random.rand(100)
y2 = np.random.rand(100)

plt.scatter(x1, y1, marker="+")
plt.scatter(x2, y2, marker="x")
plt.show()

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/datagy/data/main/KNN_data.csv')
df
# Out:
#             x         y   Label
# 0    5.539907  2.780370  Medium
# 1    5.309798  3.342864   Large
# 2    4.367271  4.551839   Large
# 3    3.812863  2.447711   Large
# 4    5.213783  5.133856   Large
# ..        ...       ...     ...
# 95 -10.973173 -6.348612   Small
# 96 -12.787083 -5.901621   Small
# 97 -12.365544 -7.557758   Small
# 98 -12.201273 -9.228887   Small
# 99 -13.375726 -8.303337   Small
#
# [100 rows x 3 columns]

# %%
# Label 의 값이 Small, Medium, Large인 데이터(dataframe)를 scatter 그래프로 표현하시오.
## (1) 컬럼이 Label인 데이터 값을 다 가져온다.
## (2) 가져온 값에서 조건을 추가한다. Label == "Large"

df_large = df[df['Label'] == "Large"]
df_medium = df[df['Label'] == "Medium"]
df_small = df[df['Label'] == "Small"]

ax = df_small.plot(x='x', y='y', kind='scatter', c='r', label="Small")
df_medium.plot(x='x', y='y', kind='scatter', c='g', label="Medium", ax=ax)
df_large.plot(x='x', y='y', kind='scatter', c='b', label="Large", ax=ax)

# plt.scatter(df_small['x'], df_small['y'], c='r', label="Small")
# plt.scatter(df_medium['x'], df_medium['y'], c='g', label="Medium")
# plt.scatter(df_large['x'], df_large['y'], c='b', label="Large")


plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ## Boxplot (상자 도표)
#
# - 내가 분석하고자하는 데이터의 범위를 시각화 한 것입니다.
# - 평균값에서 너무 크게 동떨어지는 데이터를 찾아내고 => 제거 후 분석을 하기 위함입니다.

# %%
s1 = np.random.normal(loc=0, scale=1, size=1000) # loc는 평균, scale는 표준편차
s2 = np.random.normal(loc=5, scale=0.5, size=1000)
s3 = np.random.normal(loc=10, scale=2, size=1000)

# %%
plt.boxplot((s1,s2,s3))
plt.grid()
plt.show()

# %% [markdown]
# ## 파이 그래프 (원 그래프)

# %%
values = [35, 25, 15, 13, 10, 2] # 과목 선호도 점수
labels = ["Math", "Art", "Korean", "English", "Physics", "Music"]

explode = [0.05] * 6
plt.pie(values, labels=labels, autopct="%.1f", explode=explode)
plt.title("과목 선호도")
plt.legend(loc=(1.3,0.3), title="Subjects")
plt.show()

# %%
values = [100, 130, 150]
labels = ['kor', 'usa', 'china']
colors = ['r', 'g', 'b']

plt.bar(labels, values, color=colors, alpha=0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(labels, values, color=colors, alpha=0.5)
plt.ylim(90, 160)
plt.bar_label((10, 20, 30))

plt.xticks(rotation=90) # x축의 이름 데이터 각도를 90도로 설정
# plt.yticks(rotation=90) # y축의 이름 데이터 각도를 90도로 설정
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-d662a0f0db4e> in <cell line: 3>()
#       1 plt.bar(labels, values, color=colors, alpha=0.5)
#       2 plt.ylim(90, 160)
# ----> 3 plt.bar_label((10, 20, 30))
#       4
#       5 plt.xticks(rotation=90) # x축의 이름 데이터 각도를 90도로 설정
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in bar_label(container, labels, fmt, label_type, padding, **kwargs)
#    2465         container, labels=None, *, fmt='%g', label_type='edge',
#    2466         padding=0, **kwargs):
# -> 2467     return gca().bar_label(
#    2468         container, labels=labels, fmt=fmt, label_type=label_type,
#    2469         padding=padding, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py in bar_label(self, container, labels, fmt, label_type, padding, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 생성
labels = ['A', 'B', 'C', 'D']
data = np.array([10, 30, 20, 25])

# 그래프 그리기
fig, ax = plt.subplots()
ax.bar(labels, data)

# 막대 위에 숫자 표시
for i, v in enumerate(data):
    ax.text(i, v+1, str(v), ha='center', fontweight='bold')

plt.show()

# %% [markdown]
# ## 연습문제

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import matplotlib.pyplot as plt
import numpy as np
plt.rc('font', family='NanumBarunGothic')

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    '영화' : ['명량', '극한직업', '신과함께-죄와 벌', '국제시장', '괴물', '도둑들', '7번방의 선물', '암살'],
    '개봉 연도' : [2014, 2019, 2017, 2014, 2006, 2012, 2013, 2015],
    '관객 수' : [1761, 1626, 1441, 1426, 1301, 1298, 1281, 1270], # (단위 : 만 명)
    '평점' : [8.88, 9.20, 8.73, 9.16, 8.62, 7.64, 8.83, 9.10]
}
df = pd.DataFrame(data)
df
# Out:
#           영화  개봉 연도  관객 수    평점
# 0         명량   2014  1761  8.88
# 1       극한직업   2019  1626  9.20
# 2  신과함께-죄와 벌   2017  1441  8.73
# 3       국제시장   2014  1426  9.16
# 4         괴물   2006  1301  8.62
# 5        도둑들   2012  1298  7.64
# 6    7번방의 선물   2013  1281  8.83
# 7         암살   2015  1270  9.10

# %%
## 1. 영화 데이터를 활용하여 x 축은 영화, y축은 평점인 막대(bar) 그래프를 만드시오.
## (1) 막대그래프
## (2) x=영화, height=평점

## 2. 앞에서 만든 막대 그래프에 제시된 세부 사항을 적용하시오.
## - 제목: 국내 Top 8 영화 평점 정보
## - x축 label: 영화 (90도 회전)
## - y축 label: 평점

## 3. 개봉 연도별 평점 변화 추이를 꺾은선 그래프(plot)로 그리시오.
## (1) 개봉 연도별 평점
## (2) x축에는 연도 데이터가 들어가야 하고, y축에는 평점 데이터가 들어가면 되겠네요.

## 4 앞에서 만든 그래프에 제시된 세부 사항을 적용하시오.
## - marker: 'o'
## - x축 눈금: 5년 단위 (2005, 2010, 2015, 2020)
## - y축 범위: 최소 7, 최대 10

# %%
## 1. 영화 데이터를 활용하여 x 축은 영화, y축은 평점인 막대(bar) 그래프를 만드시오.
## (1) 막대그래프
## (2) x=영화, height=평점

plt.figure(figsize=(20,8))
plt.bar(df['영화'], df['평점'])

# bars = plt.bar(df['영화'], df['평점'])

# # 막대 위에 숫자 추가
# for bar in bars:
#     plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f"{bar.get_height()}", ha='center', va='bottom')
# Out:
# <BarContainer object of 8 artists>

# %%
## 2. 앞에서 만든 막대 그래프에 제시된 세부 사항을 적용하시오.
## - 제목: 국내 Top 8 영화 평점 정보
## - x축 label: 영화 (90도 회전)
## - y축 label: 평점

plt.figure(figsize=(12,6))
plt.bar(df['영화'], df['평점'])

plt.title("국내 Top 8 영화 평점 정보")

plt.xlabel("영화")
plt.xticks(rotation=90)
plt.ylabel("평점")

plt.show()

# %%
## 3. 개봉 연도별 평점 변화 추이를 꺾은선 그래프(plot)로 그리시오.
## (1) 개봉 연도별 평점
## (2) x축에는 연도 데이터가 들어가야 하고, y축에는 평점 데이터가 들어가면 되겠네요.
df['개봉 연도']
df['평점']


df_group = df.groupby('개봉 연도').mean()
plt.plot(df_group.index, df_group['평점'])

# %%
## 4) 앞에서 만든 그래프에 제시된 세부 사항을 적용하시오.
## - marker: 'o'
## - x축 눈금: 5년 단위 (2005, 2010, 2015, 2020)
## - y축 범위: 최소 7, 최대 10

df_group = df.groupby('개봉 연도').mean()
plt.plot(df_group.index, df_group['평점'], marker='o')
plt.xticks([2005, 2010, 2015, 2020])
plt.ylim(7, 10)
# Out:
# (7.0, 10.0)

# %%
## 5) 평점이 9점 이상인 영화의 비율을 확인할 수 있는 원 그래프(파이차트)를 제시된 세부 사항을 적용하여 그리시오.
## - label: 9점 이상 / 9점 미만
## - 퍼센트: 소수점 첫 번째 자리까지 표시
## - 범례: 그래프 우측에 표시

high_avg = df['평점'] >= 9.0

high_rating_num = len(df[high_avg])
low_rating_num = len(df[~high_avg])

values = [high_rating_num, low_rating_num]

labels = ["9점 이상", "9점 미만"]

plt.pie(values, labels=labels, autopct="%.1f%%")
plt.legend(loc=(1, 0.1))

plt.show()

# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt

vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


fig, ax = plt.subplots()
im = ax.imshow(harvest)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(farmers)), labels=farmers)
ax.set_yticks(np.arange(len(vegetables)), labels=vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()
